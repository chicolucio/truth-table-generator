# %%
import ttg

# %% [markdown]
# Functions to be applied. You can create your own functions as shown [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html).

# %%
def color_false_red(val):
    """Color red False (0) and green True (1) values"""
    color = 'red' if (val == False) else 'green'
    return 'color: %s' % color


def df_style(logic, hl_rows=[], hl_cols=[]):
    """Applies style to logical expression (logic) pandas truth table. 
    Text: center. Table: no index column. Highlight yellow rows and columns in 
    lists (hl_rows and hl_cols). At the end applies color_false_red function"""
    d = logic.as_pandas().style.set_table_styles([{
        'selector':
        'th',
        'props': [('font-size', '12pt')]
    }]).set_properties(**{
        'text-align': 'center',
        'font-size': '115%'
    }).apply(
        lambda x:
        ['background: lightyellow' if x.name in hl_rows else '' for i in x],
        axis=1).apply(lambda x: [
            'background: lightyellow' if x.name in hl_cols else '' for i in x
        ],
                      axis=0).hide_index()
    d = d.applymap(color_false_red)
    return d

# %%
# creating a table
table = ttg.Truths(['p', 'q'],
                   ['p => q', 'q => p', '(p => q) and (q => p)', 'p = q'],
                   ints=False)

# %%
# applying style. Without lists of rows and columns to highlight.
df_style(table)
# Out:
# <style  type="text/css" >
#     #T_0b45152a_f021_11e9_bee2_0c96e6ec4f2f th {
#           font-size: 12pt;
#     }    #T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow0_col0 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow0_col1 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow0_col2 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow0_col3 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow0_col4 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow0_col5 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow1_col0 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow1_col1 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  red;
#         }    #T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow1_col2 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  red;
#         }    #T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow1_col3 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow1_col4 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  red;
#         }    #T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow1_col5 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  red;
#         }    #T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow2_col0 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  red;
#         }    #T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow2_col1 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow2_col2 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow2_col3 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  red;
#         }    #T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow2_col4 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  red;
#         }    #T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow2_col5 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  red;
#         }    #T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow3_col0 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  red;
#         }    #T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow3_col1 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  red;
#         }    #T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow3_col2 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow3_col3 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow3_col4 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow3_col5 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }</style><table id="T_0b45152a_f021_11e9_bee2_0c96e6ec4f2f" ><thead>    <tr>        <th class="col_heading level0 col0" >p</th>        <th class="col_heading level0 col1" >q</th>        <th class="col_heading level0 col2" >p => q</th>        <th class="col_heading level0 col3" >q => p</th>        <th class="col_heading level0 col4" >(p => q) and (q => p)</th>        <th class="col_heading level0 col5" >p = q</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow0_col0" class="data row0 col0" >True</td>
#                         <td id="T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow0_col1" class="data row0 col1" >True</td>
#                         <td id="T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow0_col2" class="data row0 col2" >True</td>
#                         <td id="T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow0_col3" class="data row0 col3" >True</td>
#                         <td id="T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow0_col4" class="data row0 col4" >True</td>
#                         <td id="T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow0_col5" class="data row0 col5" >True</td>
#             </tr>
#             <tr>
#                                 <td id="T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow1_col0" class="data row1 col0" >True</td>
#                         <td id="T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow1_col1" class="data row1 col1" >False</td>
#                         <td id="T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow1_col2" class="data row1 col2" >False</td>
#                         <td id="T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow1_col3" class="data row1 col3" >True</td>
#                         <td id="T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow1_col4" class="data row1 col4" >False</td>
#                         <td id="T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow1_col5" class="data row1 col5" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow2_col0" class="data row2 col0" >False</td>
#                         <td id="T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow2_col1" class="data row2 col1" >True</td>
#                         <td id="T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow2_col2" class="data row2 col2" >True</td>
#                         <td id="T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow2_col3" class="data row2 col3" >False</td>
#                         <td id="T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow2_col4" class="data row2 col4" >False</td>
#                         <td id="T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow2_col5" class="data row2 col5" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow3_col0" class="data row3 col0" >False</td>
#                         <td id="T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow3_col1" class="data row3 col1" >False</td>
#                         <td id="T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow3_col2" class="data row3 col2" >True</td>
#                         <td id="T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow3_col3" class="data row3 col3" >True</td>
#                         <td id="T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow3_col4" class="data row3 col4" >True</td>
#                         <td id="T_0b45152a_f021_11e9_bee2_0c96e6ec4f2frow3_col5" class="data row3 col5" >True</td>
#             </tr>
#     </tbody></table>

# %%
# highlighting rows 2 and 4
df_style(table, hl_rows=[2, 4])
# Out:
# <style  type="text/css" >
#     #T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2f th {
#           font-size: 12pt;
#     }    #T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow0_col0 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow0_col1 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow0_col2 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow0_col3 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow0_col4 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow0_col5 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow1_col0 {
#             text-align:  center;
#             font-size:  115%;
#             background:  lightyellow;
#             : ;
#             color:  green;
#         }    #T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow1_col1 {
#             text-align:  center;
#             font-size:  115%;
#             background:  lightyellow;
#             : ;
#             color:  red;
#         }    #T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow1_col2 {
#             text-align:  center;
#             font-size:  115%;
#             background:  lightyellow;
#             : ;
#             color:  red;
#         }    #T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow1_col3 {
#             text-align:  center;
#             font-size:  115%;
#             background:  lightyellow;
#             : ;
#             color:  green;
#         }    #T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow1_col4 {
#             text-align:  center;
#             font-size:  115%;
#             background:  lightyellow;
#             : ;
#             color:  red;
#         }    #T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow1_col5 {
#             text-align:  center;
#             font-size:  115%;
#             background:  lightyellow;
#             : ;
#             color:  red;
#         }    #T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow2_col0 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  red;
#         }    #T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow2_col1 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow2_col2 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow2_col3 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  red;
#         }    #T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow2_col4 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  red;
#         }    #T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow2_col5 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  red;
#         }    #T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow3_col0 {
#             text-align:  center;
#             font-size:  115%;
#             background:  lightyellow;
#             : ;
#             color:  red;
#         }    #T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow3_col1 {
#             text-align:  center;
#             font-size:  115%;
#             background:  lightyellow;
#             : ;
#             color:  red;
#         }    #T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow3_col2 {
#             text-align:  center;
#             font-size:  115%;
#             background:  lightyellow;
#             : ;
#             color:  green;
#         }    #T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow3_col3 {
#             text-align:  center;
#             font-size:  115%;
#             background:  lightyellow;
#             : ;
#             color:  green;
#         }    #T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow3_col4 {
#             text-align:  center;
#             font-size:  115%;
#             background:  lightyellow;
#             : ;
#             color:  green;
#         }    #T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow3_col5 {
#             text-align:  center;
#             font-size:  115%;
#             background:  lightyellow;
#             : ;
#             color:  green;
#         }</style><table id="T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2f" ><thead>    <tr>        <th class="col_heading level0 col0" >p</th>        <th class="col_heading level0 col1" >q</th>        <th class="col_heading level0 col2" >p => q</th>        <th class="col_heading level0 col3" >q => p</th>        <th class="col_heading level0 col4" >(p => q) and (q => p)</th>        <th class="col_heading level0 col5" >p = q</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow0_col0" class="data row0 col0" >True</td>
#                         <td id="T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow0_col1" class="data row0 col1" >True</td>
#                         <td id="T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow0_col2" class="data row0 col2" >True</td>
#                         <td id="T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow0_col3" class="data row0 col3" >True</td>
#                         <td id="T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow0_col4" class="data row0 col4" >True</td>
#                         <td id="T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow0_col5" class="data row0 col5" >True</td>
#             </tr>
#             <tr>
#                                 <td id="T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow1_col0" class="data row1 col0" >True</td>
#                         <td id="T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow1_col1" class="data row1 col1" >False</td>
#                         <td id="T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow1_col2" class="data row1 col2" >False</td>
#                         <td id="T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow1_col3" class="data row1 col3" >True</td>
#                         <td id="T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow1_col4" class="data row1 col4" >False</td>
#                         <td id="T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow1_col5" class="data row1 col5" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow2_col0" class="data row2 col0" >False</td>
#                         <td id="T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow2_col1" class="data row2 col1" >True</td>
#                         <td id="T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow2_col2" class="data row2 col2" >True</td>
#                         <td id="T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow2_col3" class="data row2 col3" >False</td>
#                         <td id="T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow2_col4" class="data row2 col4" >False</td>
#                         <td id="T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow2_col5" class="data row2 col5" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow3_col0" class="data row3 col0" >False</td>
#                         <td id="T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow3_col1" class="data row3 col1" >False</td>
#                         <td id="T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow3_col2" class="data row3 col2" >True</td>
#                         <td id="T_18ae53ac_f021_11e9_bee2_0c96e6ec4f2frow3_col3" class="data row3 col3" >True</td>
#                         <td id="T_18ae53ac_f021

# %%
# highlighting columns named 'p' and 'p = q'
df_style(table, hl_cols=['p', 'p = q'])
# Out:
# <style  type="text/css" >
#     #T_27595b72_f021_11e9_bee2_0c96e6ec4f2f th {
#           font-size: 12pt;
#     }    #T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow0_col0 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             background:  lightyellow;
#             color:  green;
#         }    #T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow0_col1 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow0_col2 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow0_col3 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow0_col4 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow0_col5 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             background:  lightyellow;
#             color:  green;
#         }    #T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow1_col0 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             background:  lightyellow;
#             color:  green;
#         }    #T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow1_col1 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  red;
#         }    #T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow1_col2 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  red;
#         }    #T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow1_col3 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow1_col4 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  red;
#         }    #T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow1_col5 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             background:  lightyellow;
#             color:  red;
#         }    #T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow2_col0 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             background:  lightyellow;
#             color:  red;
#         }    #T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow2_col1 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow2_col2 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow2_col3 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  red;
#         }    #T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow2_col4 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  red;
#         }    #T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow2_col5 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             background:  lightyellow;
#             color:  red;
#         }    #T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow3_col0 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             background:  lightyellow;
#             color:  red;
#         }    #T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow3_col1 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  red;
#         }    #T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow3_col2 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow3_col3 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow3_col4 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow3_col5 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             background:  lightyellow;
#             color:  green;
#         }</style><table id="T_27595b72_f021_11e9_bee2_0c96e6ec4f2f" ><thead>    <tr>        <th class="col_heading level0 col0" >p</th>        <th class="col_heading level0 col1" >q</th>        <th class="col_heading level0 col2" >p => q</th>        <th class="col_heading level0 col3" >q => p</th>        <th class="col_heading level0 col4" >(p => q) and (q => p)</th>        <th class="col_heading level0 col5" >p = q</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow0_col0" class="data row0 col0" >True</td>
#                         <td id="T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow0_col1" class="data row0 col1" >True</td>
#                         <td id="T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow0_col2" class="data row0 col2" >True</td>
#                         <td id="T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow0_col3" class="data row0 col3" >True</td>
#                         <td id="T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow0_col4" class="data row0 col4" >True</td>
#                         <td id="T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow0_col5" class="data row0 col5" >True</td>
#             </tr>
#             <tr>
#                                 <td id="T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow1_col0" class="data row1 col0" >True</td>
#                         <td id="T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow1_col1" class="data row1 col1" >False</td>
#                         <td id="T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow1_col2" class="data row1 col2" >False</td>
#                         <td id="T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow1_col3" class="data row1 col3" >True</td>
#                         <td id="T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow1_col4" class="data row1 col4" >False</td>
#                         <td id="T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow1_col5" class="data row1 col5" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow2_col0" class="data row2 col0" >False</td>
#                         <td id="T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow2_col1" class="data row2 col1" >True</td>
#                         <td id="T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow2_col2" class="data row2 col2" >True</td>
#                         <td id="T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow2_col3" class="data row2 col3" >False</td>
#                         <td id="T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow2_col4" class="data row2 col4" >False</td>
#                         <td id="T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow2_col5" class="data row2 col5" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow3_col0" class="data row3 col0" >False</td>
#                         <td id="T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow3_col1" class="data row3 col1" >False</td>
#                         <td id="T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow3_col2" class="data row3 col2" >True</td>
#                         <td id="T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow3_col3" class="data row3 col3" >True</td>
#                         <td id="T_27595b72_f021_11e9_bee2_0c96e6ec4f2frow3_col4" class="data row3 col4" >True</td>

# %%
# highlighting rowns and columns
df_style(table, hl_rows = [2, 4], hl_cols=['p', 'p = q'])
# Out:
# <style  type="text/css" >
#     #T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2f th {
#           font-size: 12pt;
#     }    #T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow0_col0 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             background:  lightyellow;
#             color:  green;
#         }    #T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow0_col1 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow0_col2 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow0_col3 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow0_col4 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow0_col5 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             background:  lightyellow;
#             color:  green;
#         }    #T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow1_col0 {
#             text-align:  center;
#             font-size:  115%;
#             background:  lightyellow;
#             background:  lightyellow;
#             color:  green;
#         }    #T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow1_col1 {
#             text-align:  center;
#             font-size:  115%;
#             background:  lightyellow;
#             : ;
#             color:  red;
#         }    #T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow1_col2 {
#             text-align:  center;
#             font-size:  115%;
#             background:  lightyellow;
#             : ;
#             color:  red;
#         }    #T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow1_col3 {
#             text-align:  center;
#             font-size:  115%;
#             background:  lightyellow;
#             : ;
#             color:  green;
#         }    #T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow1_col4 {
#             text-align:  center;
#             font-size:  115%;
#             background:  lightyellow;
#             : ;
#             color:  red;
#         }    #T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow1_col5 {
#             text-align:  center;
#             font-size:  115%;
#             background:  lightyellow;
#             background:  lightyellow;
#             color:  red;
#         }    #T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow2_col0 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             background:  lightyellow;
#             color:  red;
#         }    #T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow2_col1 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow2_col2 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  green;
#         }    #T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow2_col3 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  red;
#         }    #T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow2_col4 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             : ;
#             color:  red;
#         }    #T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow2_col5 {
#             text-align:  center;
#             font-size:  115%;
#             : ;
#             background:  lightyellow;
#             color:  red;
#         }    #T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow3_col0 {
#             text-align:  center;
#             font-size:  115%;
#             background:  lightyellow;
#             background:  lightyellow;
#             color:  red;
#         }    #T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow3_col1 {
#             text-align:  center;
#             font-size:  115%;
#             background:  lightyellow;
#             : ;
#             color:  red;
#         }    #T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow3_col2 {
#             text-align:  center;
#             font-size:  115%;
#             background:  lightyellow;
#             : ;
#             color:  green;
#         }    #T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow3_col3 {
#             text-align:  center;
#             font-size:  115%;
#             background:  lightyellow;
#             : ;
#             color:  green;
#         }    #T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow3_col4 {
#             text-align:  center;
#             font-size:  115%;
#             background:  lightyellow;
#             : ;
#             color:  green;
#         }    #T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow3_col5 {
#             text-align:  center;
#             font-size:  115%;
#             background:  lightyellow;
#             background:  lightyellow;
#             color:  green;
#         }</style><table id="T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2f" ><thead>    <tr>        <th class="col_heading level0 col0" >p</th>        <th class="col_heading level0 col1" >q</th>        <th class="col_heading level0 col2" >p => q</th>        <th class="col_heading level0 col3" >q => p</th>        <th class="col_heading level0 col4" >(p => q) and (q => p)</th>        <th class="col_heading level0 col5" >p = q</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow0_col0" class="data row0 col0" >True</td>
#                         <td id="T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow0_col1" class="data row0 col1" >True</td>
#                         <td id="T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow0_col2" class="data row0 col2" >True</td>
#                         <td id="T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow0_col3" class="data row0 col3" >True</td>
#                         <td id="T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow0_col4" class="data row0 col4" >True</td>
#                         <td id="T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow0_col5" class="data row0 col5" >True</td>
#             </tr>
#             <tr>
#                                 <td id="T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow1_col0" class="data row1 col0" >True</td>
#                         <td id="T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow1_col1" class="data row1 col1" >False</td>
#                         <td id="T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow1_col2" class="data row1 col2" >False</td>
#                         <td id="T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow1_col3" class="data row1 col3" >True</td>
#                         <td id="T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow1_col4" class="data row1 col4" >False</td>
#                         <td id="T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow1_col5" class="data row1 col5" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow2_col0" class="data row2 col0" >False</td>
#                         <td id="T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow2_col1" class="data row2 col1" >True</td>
#                         <td id="T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow2_col2" class="data row2 col2" >True</td>
#                         <td id="T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow2_col3" class="data row2 col3" >False</td>
#                         <td id="T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow2_col4" class="data row2 col4" >False</td>
#                         <td id="T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow2_col5" class="data row2 col5" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow3_col0" class="data row3 col0" >False</td>
#                         <td id="T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow3_col1" class="data row3 col1" >False</td>
#                         <td id="T_31b48bb4_f021_11e9_bee2_0c96e6ec4f2frow3_col2" class="data row3 col
